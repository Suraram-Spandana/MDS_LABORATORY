# %% [markdown]
# <a href="https://colab.research.google.com/github/Suraram-Spandana/MDS_LABORATORY/blob/main/week5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data=[10,20,30,40]
s=pd.Series(data)
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
data=[10,20,30]
s=pd.Series(data,index=['a','b','c'])
print(s)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
data = {
    'A': 10,
    'B': 20,
    'C': 30
}

s = pd.Series(data)

print(s)
# Out:
# A    10
# B    20
# C    30
# dtype: int64

# %%
s = pd.Series(5, index=['a', 'b', 'c'])

print(s)
# Out:
# a    5
# b    5
# c    5
# dtype: int64

# %%
import pandas as pd

df = pd.read_csv("/Employee.csv")

print(df)
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
import pandas as pd

df = pd.read_csv("/Employee.csv")

print(df.head())
# Out:
#    Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0  Bachelors         2017  Bangalore            3   34    Male          No
# 1  Bachelors         2013       Pune            1   28  Female          No
# 2  Bachelors         2014  New Delhi            3   38  Female          No
# 3    Masters         2016  Bangalore            3   27    Male          No
# 4    Masters         2017       Pune            3   24    Male         Yes
#
#    ExperienceInCurrentDomain  LeaveOrNot
# 0                          0           0
# 1                          3           1
# 2                          2           0
# 3                          5           1
# 4                          2           1

# %%
print(df.head())       # First 5 rows
print(df.tail())       # Last 5 rows
print(df.columns)      # Column names
print(df.shape)        # Number of rows and columns
print(df.info())       # Data types and information
# Out:
#    Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0  Bachelors         2017  Bangalore            3   34    Male          No
# 1  Bachelors         2013       Pune            1   28  Female          No
# 2  Bachelors         2014  New Delhi            3   38  Female          No
# 3    Masters         2016  Bangalore            3   27    Male          No
# 4    Masters         2017       Pune            3   24    Male         Yes
#
#    ExperienceInCurrentDomain  LeaveOrNot
# 0                          0           0
# 1                          3           1
# 2                          2           0
# 3                          5           1
# 4                          2           1
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# ...

# %%
print(df.head(10))
print(df.tail(10))
# Out:
#    Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0  Bachelors         2017  Bangalore            3   34    Male          No
# 1  Bachelors         2013       Pune            1   28  Female          No
# 2  Bachelors         2014  New Delhi            3   38  Female          No
# 3    Masters         2016  Bangalore            3   27    Male          No
# 4    Masters         2017       Pune            3   24    Male         Yes
# 5  Bachelors         2016  Bangalore            3   22    Male          No
# 6  Bachelors         2015  New Delhi            3   38    Male          No
# 7  Bachelors         2016  Bangalore            3   34  Female          No
# 8  Bachelors         2016       Pune            3   23    Male          No
# 9    Masters         2017  New Delhi            2   37    Male          No
#
#    ExperienceInCurrentDomain  LeaveOrNot
# 0                          0           0
# 1                          3           1
# ...

# %%
print(df.shape)
print(df.index)
# Out:
# (4653, 9)
# RangeIndex(start=0, stop=4653, step=1)

# %%
print(df["Name"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_964/3201711211.py in <cell line: 0>()
# ----> 1 print(df["Name"])
#
# ...

# %%
print(df[df["Age"]>30])
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 6     Bachelors         2015  New Delhi            3   38    Male          No
# 7     Bachelors         2016  Bangalore            3   34  Female          No
# 9       Masters         2017  New Delhi            2   37    Male          No
# ...         ...          ...        ...          ...  ...     ...         ...
# 4643  Bachelors         2013  Bangalore            3   31  Female          No
# 4644  Bachelors         2015       Pune            3   32  Female         Yes
# 4645    Masters         2017       Pune            2   31  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
print(df[df["City"]=="Bangalore"])
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 5     Bachelors         2016  Bangalore            3   22    Male          No
# 7     Bachelors         2016  Bangalore            3   34  Female          No
# 10      Masters         2012  Bangalore            3   27    Male          No
# ...         ...          ...        ...          ...  ...     ...         ...
# 4643  Bachelors         2013  Bangalore            3   31  Female          No
# 4646  Bachelors         2013  Bangalore            3   25  Female          No
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
print(df[df["PaymentTier"] == 1])
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 1     Bachelors         2013       Pune            1   28  Female          No
# 15    Bachelors         2017  Bangalore            1   29    Male          No
# 35    Bachelors         2014  Bangalore            1   30  Female          No
# 63    Bachelors         2014       Pune            1   22  Female          No
# 73    Bachelors         2014  Bangalore            1   27    Male          No
# ...         ...          ...        ...          ...  ...     ...         ...
# 4587  Bachelors         2014       Pune            1   33  Female          No
# 4609  Bachelors         2014       Pune            1   22  Female          No
# 4622  Bachelors         2017       Pune            1   30    Male          No
# 4634  Bachelors         2016  New Delhi            1   38  Female          No
# 4641  Bachelors         2016  Bangalore            1   33  Female          No
#
# ...

# %%
print(df[(df["Age"] > 30) & (df["PaymentTier"] == 1)])
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 79          PHD         2015  New Delhi            1   37    Male          No
# 2994  Bachelors         2013       Pune            1   39  Female          No
# 3096  Bachelors         2012  Bangalore            1   36    Male          No
# 3102    Masters         2015  New Delhi            1   34    Male          No
# 3103    Masters         2017  New Delhi            1   40    Male          No
# ...         ...          ...        ...          ...  ...     ...         ...
# 4565  Bachelors         2015  Bangalore            1   35    Male          No
# 4584  Bachelors         2015       Pune            1   39    Male          No
# 4587  Bachelors         2014       Pune            1   33  Female          No
# 4634  Bachelors         2016  New Delhi            1   38  Female          No
# 4641  Bachelors         2016  Bangalore            1   33  Female          No
#
# ...

# %%
df.drop("Gender", axis=2, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     575         try:
# --> 576             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     577         except KeyError:
#
# KeyError: 2
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_964/326683893.py in <cell line: 0>()
# ----> 1 df.drop("Gender", axis=2, inplace=True)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# ...

# %%
df.drop(["Gender", "EverBenched"], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_964/2559929050.py in <cell line: 0>()
# ----> 1 df.drop(["Gender", "EverBenched"], axis=1, inplace=True)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
df.drop(df[df["Age"] < 20].index, inplace=True)

# %%
print(df.sort_values("Age"))
# Out:
#       Education  JoiningYear       City  PaymentTier  Age EverBenched  \
# 4069    Masters         2013  New Delhi            2   22         Yes
# 4539  Bachelors         2014  Bangalore            3   22          No
# 4048  Bachelors         2014  Bangalore            3   22          No
# 4070  Bachelors         2015       Pune            1   22          No
# 4561  Bachelors         2013  Bangalore            3   22          No
# ...         ...          ...        ...          ...  ...         ...
# 3394  Bachelors         2013  Bangalore            3   41          No
# 3355  Bachelors         2016  Bangalore            3   41          No
# 3500  Bachelors         2017  Bangalore            3   41          No
# 3527  Bachelors         2017  New Delhi            3   41          No
# 3386    Masters         2013       Pune            2   41          No
#
#       ExperienceInCurrentDomain  LeaveOrNot
# 4069                          0           1
# ...

# %%
print(df.sort_values("Age", ascending=False))
# Out:
#       Education  JoiningYear       City  PaymentTier  Age EverBenched  \
# 3017  Bachelors         2017  Bangalore            3   41         Yes
# 3031  Bachelors         2013  New Delhi            3   41          No
# 3033  Bachelors         2017  New Delhi            2   41          No
# 3055  Bachelors         2012  Bangalore            3   41          No
# 3048    Masters         2013  New Delhi            3   41          No
# ...         ...          ...        ...          ...  ...         ...
# 4635  Bachelors         2014  Bangalore            3   22          No
# 4119  Bachelors         2015  New Delhi            3   22          No
# 4572  Bachelors         2014       Pune            1   22          No
# 5     Bachelors         2016  Bangalore            3   22          No
# 25    Bachelors         2013  Bangalore            3   22         Yes
#
#       ExperienceInCurrentDomain  LeaveOrNot
# 3017                          3           0
# ...

# %%
df["Age_Rank"] = df["Age"].rank(ascending=False)

print(df[["Age", "Age_Rank"]])
# Out:
#       Age  Age_Rank
# 0      34     954.5
# 1      28    2168.5
# 2      38     415.5
# 3      27    2796.0
# 4      24    4364.0
# ...   ...       ...
# 4648   26    3431.0
# 4649   37     554.0
# 4650   27    2796.0
# 4651   30    1513.5
# 4652   33    1084.5
#
# [4653 rows x 2 columns]

# %%
print("Mean:", df["Age"].mean())
print("Median:", df["Age"].median())
print("Minimum:", df["Age"].min())
print("Maximum:", df["Age"].max())
print("Sum:", df["Age"].sum())
print("Standard Deviation:", df["Age"].std())
print("Variance:", df["Age"].var())
# Out:
# Mean: 29.393294648613796
# Median: 28.0
# Minimum: 22
# Maximum: 41
# Sum: 136767
# Standard Deviation: 4.826087009126047
# Variance: 23.29111581965519

# %%
print(df.describe())
# Out:
#        JoiningYear  PaymentTier          Age  ExperienceInCurrentDomain  \
# count  4653.000000  4653.000000  4653.000000                4653.000000
# mean   2015.062970     2.698259    29.393295                   2.905652
# std       1.863377     0.561435     4.826087                   1.558240
# min    2012.000000     1.000000    22.000000                   0.000000
# 25%    2013.000000     3.000000    26.000000                   2.000000
# 50%    2015.000000     3.000000    28.000000                   3.000000
# 75%    2017.000000     3.000000    32.000000                   4.000000
# max    2018.000000     3.000000    41.000000                   7.000000
#
#         LeaveOrNot     Age_Rank
# count  4653.000000  4653.000000
# mean      0.343864  2327.000000
# std       0.475047  1337.071592
# min       0.000000    41.500000
# 25%       0.000000  1212.500000
# 50%       0.000000  2168.500000
# 75%       1.000000  3431.000000
# max       1.000000  4629.000000

# %%
print(df["Education"].unique())
# Out:
# ['Bachelors' 'Masters' 'PHD']

# %%
print(df["Education"].nunique())
# Out:
# 3

# %%
print(df["Education"].value_counts())
# Out:
# Education
# Bachelors    3601
# Masters       873
# PHD           179
# Name: count, dtype: int64

# %%
print(df["LeaveOrNot"].value_counts())
# Out:
# LeaveOrNot
# 0    3053
# 1    1600
# Name: count, dtype: int64

# %%
df.rename(columns={"Age": "EmployeeAge"}, inplace=True)

# %%
df.rename(columns={"Age": "EmployeeAge"}, inplace=True)

# %%
print(df.columns)
# Out:
# Index(['Education', 'JoiningYear', 'City', 'PaymentTier', 'EmployeeAge',
#        'EverBenched', 'ExperienceInCurrentDomain', 'LeaveOrNot', 'Age_Rank'],
#       dtype='object')

# %%
print(df.columns)
# Out:
# Index(['Education', 'JoiningYear', 'City', 'PaymentTier', 'EmployeeAge',
#        'EverBenched', 'ExperienceInCurrentDomain', 'LeaveOrNot', 'Age_Rank'],
#       dtype='object')

# %%
df.rename(columns={
    "JoiningYear": "Joining_Year",
    "PaymentTier": "Payment_Tier",
    "ExperienceInCurrentDomain": "Domain_Experience"
}, inplace=True)

# %%
print(df.columns)
# Out:
# Index(['Education', 'Joining_Year', 'City', 'Payment_Tier', 'EmployeeAge',
#        'EverBenched', 'Domain_Experience', 'LeaveOrNot', 'Age_Rank'],
#       dtype='object')
